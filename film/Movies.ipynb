# %%
# Data   : Film Hollywood 
# Source : https://github.com/gchan/hollywood-budgets/blob/master/public/data/Most%20Profitable%20Hollywood%20Stories.csv
# Format : .csv
# Ukuran : 640 baris x 15 kolom

# %%
import pandas as pd

df = pd.read_csv("Movies.csv")

# %%
# Preview Data 

display(pd.DataFrame(df[:5]))
# Out:
#                              Film Lead Studio  Rotten Tomatoes  \
# 0               College Road Trip         NaN             13.0
# 1                   Imagine That          NaN             38.0
# 2                   Your Highness   Universal             26.0
# 3  Walk Hard: The Dewey Cox Story        Sony             75.0
# 4                   The Love Guru   Paramount             14.0
#
#    Audience Score   Story      Genre  \
# 0            56.0  Comedy  Adventure
# 1            44.0  Comedy     Comedy
# 2            36.0  Comedy     Comedy
# 3            55.0  Comedy     Comedy
# 4            38.0  Comedy     Comedy
#
#    Number of Theatres in US Opening Weekend  \
# 0                                    2706.0
# 1                                    3008.0
# 2                                    2769.0
# 3                                    2650.0
# 4                                    3505.0
#
#    Box Office Average per US Cinema (Opening Weekend)  Domestic Gross  \
# ...

# %%
# Atribut Data

# 1. Film                                               : Judul film                                                                       :
# 2. Lead Studio                                        : Studio film                                                                      :
# 3. Rotten Tomatoes                                    : Score film menurut https://www.rottentomatoes.com/                               :
# 4. Audience Score                                     : Score film menurut penonton                                                      :
# 5. Story                                              : Tipe cerita                                                                      :
# 6. Genre                                              : Genre film                                                                       :
# 7. Number of Theatres in US Opening Weekend           : Banyaknya bioskop yang menayangkan film pada opening weekend                     :
# 8. Box Office Average per US Cinema (Opening Weekend) : Rata-rata keuntungan kotor bioskop lokal pada opening weekend (dalam juta dolar) :
# 9. Domestic Gross                                     : Total keuntungan kotor bioskop lokal (US) (dalam juta dolar)                     :
# 10. Foreign Gross                                     : Total keuntungan kotor bioskop luar negeri (dalam juta dolar)                    :
# 11. Budget                                            : Budget film (dalam juta dolar)                                                   
# 13. Profitability                                     : Rasio keuntungan dengan modal
# 14. Opening Weekend                                   : Total keuntungan kotor pada opening weekend (dalam juta dolar)
# 15. Year                                              : Tahun rilis
